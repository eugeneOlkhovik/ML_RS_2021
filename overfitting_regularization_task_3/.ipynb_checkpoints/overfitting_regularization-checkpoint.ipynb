# %% [markdown]
# # Overfitting and Regularization

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import sys

if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, cross_validate
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.linear_model import LinearRegression, Lasso, Ridge, LassoCV
from sklearn.metrics import mean_squared_error
from sklearn import set_config

# %%
set_config(display='diagram')

# %% [markdown]
# ## Settings

# %%
SEED = 42
RANGE = (-5, 5)
N_SAMPLES =50
DEGREES = np.linspace(0, 15, 1 + 15, dtype=int)
ALPHAS = np.linspace(0, 0.5, 1 + 40)

# %% [markdown]
# ## Part 1: Underfitting vs. overfitting

# %% [markdown]
# ### Generate samples

# %% [markdown]
# Let's pick a target function $ f(x) = 2\cdot x + 10\cdot sin(x) $ and generate some noisy samples to learn from.

# %%
def target_function(x):
    return 2 * x + 10 * np.sin(x)

def generate_samples():
    """Generate noisy samples."""
    np.random.seed(SEED)
    x = np.random.uniform(*RANGE, size=N_SAMPLES)
    y = target_function(x) + np.random.normal(scale=4, size=N_SAMPLES)
    return x.reshape(-1, 1), y

X, y = generate_samples()

# %% [markdown]
# ### Plot samples

# %%
def plot_scatter(x, y, title=None, label='Noisy samples'):
    plt.scatter(x, y, label=label)
    plt.xlabel('x')
    plt.ylabel('y')
    plt.grid(True)
    plt.title(title)
    plt.legend(loc='lower right')

plot_scatter(X, y)

# %% [markdown]
# ### Split

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.3, random_state=SEED)

plot_scatter(X_train, y_train, label='Training set')
plot_scatter(X_valid, y_valid, label='Validation set')

# %% [markdown]
# ### Model

# %% [markdown]
# Let's try to approximate our target function $ f(x) = 2\cdot x + 10\cdot sin(x) $ with polynomials of different degree.
#
# A polynomial of degree $n$ has the form:
# $ h(x) = w_0 + w_1\cdot x + w_2\cdot x^2 +\ldots + w_n\cdot x^n $.
#
# $x^i$ values could easily be generated by `PolynomialFeatures`, while $w_i$ are the unknown paramaters to be estimated using `LinearRegression`.

# %%
PolynomialFeatures(degree=15).fit_transform(X=[
    [1],
    [3],
    [4],
])
# Out:
# array([[1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00],
#        [1.00000000e+00, 3.00000000e+00, 9.00000000e+00, 2.70000000e+01,
#         8.10000000e+01, 2.43000000e+02, 7.29000000e+02, 2.18700000e+03,
#         6.56100000e+03, 1.96830000e+04, 5.90490000e+04, 1.77147000e+05,
#         5.31441000e+05, 1.59432300e+06, 4.78296900e+06, 1.43489070e+07],
#        [1.00000000e+00, 4.00000000e+00, 1.60000000e+01, 6.40000000e+01,
#         2.56000000e+02, 1.02400000e+03, 4.09600000e+03, 1.63840000e+04,
#         6.55360000e+04, 2.62144000e+05, 1.04857600e+06, 4.19430400e+06,
#         1.67772160e+07, 6.71088640e+07, 2.68435456e+08, 1.07374182e+09]])

# %%
PolynomialFeatures(degree=15)
# Out:
# PolynomialFeatures(degree=15)

# %%
def make_model(degree, alpha=0, penalty=None):
    # linear regression
    if alpha == 0:
        regressor = LinearRegression(fit_intercept=False)
    
    # lasso regression
    elif penalty == 'L1':
        regressor = Lasso(fit_intercept=False, alpha=alpha, random_state=SEED, max_iter=500000)        
    
    # ridge regression
    elif penalty == 'L2':
        regressor = Ridge(fit_intercept=False, alpha=alpha, random_state=SEED, max_iter=500000)        
    
    return Pipeline([
        ('pol', PolynomialFeatures(degree)),
        ('sca', StandardScaler()),
        ('reg', regressor)
    ])

display(make_model(2))
display(make_model(2, penalty='L1', alpha=0.1))
display(make_model(2, penalty='L2', alpha=0.1))
# Out:
# Pipeline(steps=[('pol', PolynomialFeatures()), ('sca', StandardScaler()),
#                 ('reg', LinearRegression(fit_intercept=False))])
# Pipeline(steps=[('pol', PolynomialFeatures()), ('sca', StandardScaler()),
#                 ('reg',
#                  Lasso(alpha=0.1, fit_intercept=False, max_iter=500000,
#                        random_state=42))])
# Pipeline(steps=[('pol', PolynomialFeatures()), ('sca', StandardScaler()),
#                 ('reg',
#                  Ridge(alpha=0.1, fit_intercept=False, max_iter=500000,
#                        random_state=42))])

# %% [markdown]
# ### Fit

# %% [markdown]
# Let's fit a model and plot the hypothesis it learns:

# %%
def plot_fit(model):
    degree = model['pol'].degree
    X_range = np.linspace(*RANGE, 1000).reshape(-1, 1)
    y_pred = model.predict(X_range)
    plot_scatter(X_train, y_train, label='Training sample')
    plot_scatter(X_valid, y_valid, label='Validation sample')
    plt.plot(X_range, target_function(X_range), c='green', alpha=0.2, lw=5, label='Target function')
    plt.plot(X_range, y_pred, c='red', label='Hypothesis')
    plt.ylim((min(y) - 3, max(y) + 3))
    plt.legend(loc='best')    
    plt.title(f'Polynomial approximation: degree={degree}')
    plt.show()

plot_fit(make_model(degree=2).fit(X_train, y_train))

# %% [markdown]
# ### From underfitting to overfitting

# %% [markdown]
# We can investigate the shape of the fitted curve for different values of `degree`:

# %%
for degree in [0, 1, 2, 3, 4, 5, 10, 15, 20]:
    plot_fit(make_model(degree).fit(X_train, y_train))

# %% [markdown]
# ### Fitting graph

# %% [markdown]
# In the next step we calculate the training and the validation error for each `degree` and plot them in a single graph. The resulting graph is called the fitting graph.

# %%
def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

def plot_fitting_graph(x, metric_train, metric_valid, xlabel, ylabel, 
                       custom_metric=None, custom_label='', custom_scale='log', title='Fitting graph'):
    plt.figure(figsize=(9, 4.5))
    plt.plot(x, metric_train, label='Training')
    plt.plot(x, metric_valid, color='C1', label='Validation')
    plt.axvline(x[np.argmin(metric_valid)], color='C1', lw=10, alpha=0.2)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.grid(True)
    plt.xticks(x, rotation='vertical')
    plt.legend(loc='center left')        
    if custom_metric:
        plt.twinx()
        plt.yscale(custom_scale)
        plt.plot(x, custom_metric, alpha=0.2, lw=4, ls='dotted', color='black', label=custom_label) 
        plt.legend(loc='center right')         
    plt.show()
    
rmse_train, rmse_valid = [], []
for degree in DEGREES:
    reg = make_model(degree).fit(X_train, y_train)
    rmse_train.append(rmse(reg.predict(X_train), y_train))
    rmse_valid.append(rmse(reg.predict(X_valid), y_valid))
    
plot_fitting_graph(DEGREES, rmse_train, rmse_valid, xlabel='Complexity (degree)', ylabel='Error (RMSE)', 
                   title='Least squares polynomial regression')

# %% [markdown]
# ### Sweet spot

# %% [markdown]
# What is the optimal `degree` to go with?

# %%
DEGREES[np.argmin(rmse_valid)]
# Out:
# 5

# %% [markdown]
# ### Cross-validation

# %% [markdown]
# Ideally, we would choose the the model parameters such that we have the best model performance. However, we want to make sure that we really have the best validation performance. When we do `train_test_split` we randomly split the data into two parts. What could happen is that we got lucky and split the data such that it favours the validation error. This is especially dangerous if we are dealing with small datasets. One way to check if that's the case is to run the experiment several times for different, random splits. However, there is an even more systematic way of doing this: [cross-validation](https://scikit-learn.org/stable/modules/cross_validation.html).

# %% [markdown]
# <img src="https://scikit-learn.org/stable/_images/grid_search_cross_validation.png" width=50% />

# %%
rmse_train, rmse_valid = [], []
for degree in DEGREES:
    results = cross_validate(make_model(degree), 
                             X, y, cv=5,
                             return_train_score=True,
                             scoring='neg_root_mean_squared_error')
    rmse_train.append(-np.mean(results['train_score']))
    rmse_valid.append(-np.mean(results['test_score']))
    
plot_fitting_graph(DEGREES, rmse_train, rmse_valid, xlabel='Complexity (degree)', ylabel='Error (RMSE)',
                   title='Least squares polynomial regression')

# %% [markdown]
# ### Model coefficients

# %% [markdown]
# Let's inspect our regression model coefficients:

# %%
(make_model(degree=1).fit(X_train, y_train)['reg'].coef_,
 make_model(degree=2).fit(X_train, y_train)['reg'].coef_,
 make_model(degree=5).fit(X_train, y_train)['reg'].coef_,
 make_model(degree=10).fit(X_train, y_train)['reg'].coef_)
# Out:
# (array([0.        , 2.81292778]),
#  array([0.        , 2.80049884, 0.45166501]),
#  array([  0.        ,  30.87315584,   1.48752361, -54.60227825,
#          -1.63699842,  26.62792933]),
#  array([   0.        ,   33.63850705,  -41.86346242,  -70.48743112,
#          278.98853452,   27.48125634, -656.36383501,   59.32988346,
#          651.64795186,  -47.55728814, -233.48455138]))

# %% [markdown]
# Hmm... it looks like high degree polynomials are coming with much bigger regression coefficients.
#
# We are going to plot the mean absolute value of $w_i$ as a function of degree to reveal the relationship:

# %%
rmse_train, rmse_valid, avg_coef = [], [], []
for degree in DEGREES:
    results = cross_validate(make_model(degree),
                             X, y, cv=5,
                             return_train_score=True, return_estimator=True,
                             scoring='neg_root_mean_squared_error')
    rmse_train.append(-np.mean(results['train_score']))
    rmse_valid.append(-np.mean(results['test_score']))        
    avg_coef.append(        
        # average over CV folds
        np.mean([            
            # mean absolute value of weights
            np.mean(np.abs(model['reg'].coef_))
            for model in results['estimator']
        ]))
    
plot_fitting_graph(DEGREES, rmse_train, rmse_valid,
                   xlabel='Complexity (degree)', ylabel='Error (RMSE)',
                   custom_metric=avg_coef, custom_label='avg(|$w_i$|)',
                   title='Least squares polynomial regression')

# %% [markdown]
# ### Summary

# %% [markdown]
# We observe the following:
#
# 1. **Underfitting** (degree < 5): The model is not able to fit the data properly. The fit is bad for both the training and the validation set.
#
# 2. **Fit is just right** (degree = 5): The model is able to capture the underlying data distribution. The fit is good for both the training and the validation set.
#
# 3. **Overfitting** (degree > 5): The model starts fitting the noise in the dataset. While the fit for the training data gets even better, the fit for the validation set gets worse.
#
# 4. As the order of polynomial increases, the linear model coefficients become more likely to take on **large values**.

# %% [markdown]
# ## Part 2: Regularization

# %% [markdown]
# There are two major ways to build a machine learning model with the ability to generalize well on unseen data:
# 1. Train the simplest model possible for our purpose (according to Occam’s Razor).
# 2. Train a complex or more expressive model on the data and perform regularization.
#
# Regularization is a method used to reduce the variance of a machine learning model. In other words, it is used to reduce overfitting. Regularization penalizes a model for being complex. For linear models, it means regularization forces model coefficients to be smaller in magnitude.
#
# Let's pick a polynomial model of degree **15** (which tends to overfit strongly) and try to regularize it using **L1** and **L2** penalties.

# %% [markdown]
# ### L1 - Lasso regression

# %%
rmse_train, rmse_valid = [], []
for alpha in ALPHAS:    
    results = cross_validate(make_model(degree=15, penalty='L1', alpha=alpha), 
                             X, y, cv=5,
                             return_train_score=True,
                             scoring='neg_root_mean_squared_error')
    rmse_train.append(-np.mean(results['train_score']))
    rmse_valid.append(-np.mean(results['test_score']))
    
plot_fitting_graph(ALPHAS, rmse_train, rmse_valid,
                   xlabel='Regularization strength (alpha)', ylabel='Error (RMSE)',
                   title='Lasso polynomial regression (L1): degree=15')

# %% [markdown]
# ### L2 - Ridge regression

# %%
rmse_train, rmse_valid = [], []
for alpha in ALPHAS:    
    results = cross_validate(make_model(degree=15, penalty='L2', alpha=alpha), 
                             X, y, cv=5,
                             return_train_score=True,
                             scoring='neg_root_mean_squared_error')
    rmse_train.append(-np.mean(results['train_score']))
    rmse_valid.append(-np.mean(results['test_score']))
    
plot_fitting_graph(ALPHAS, rmse_train, rmse_valid, 
                   xlabel='Regularization strength (alpha)', ylabel='Error (RMSE)', 
                   title='Ridge polynomial regression (L2): degree=15')

# %% [markdown]
# ### Summary

# %% [markdown]
# 1. We can control the regularization strength by changing the hyperparameter `alpha`.
# 2. Regularized version of the model performs pretty well. Even in case the original original (unregularized) model is heavily overfitting due to excessive complexity.

# %% [markdown]
# ## Part 3: Homework assignment (10 points)

# %% [markdown]
# ### Excercise 1 - Magnitude (4 points)

# %% [markdown]
# As discussed earlier, regularization methods are expected to constraint the weights (model coefficients).
#
# Is it indeed happening?
#
# Please do a discovery on your own and find that out empirically (both for **L1** and **L2**). Let's use `degree=15` and `alpha` from `ALPHAS`.

# %% [markdown]
# #### L1

# %%
lasso_coeff = []
PolynomialFeatures(degree=15)
for alpha in ALPHAS: 
    lasso = Lasso(alpha= alpha, max_iter=1000000)
    reg = lasso.fit(PolynomialFeatures(degree=15).fit_transform(X),y)
    print(reg.coef_)
    
    lasso_coeff.append(reg.coef_)
# Out:
# [ 0.00000000e+00  1.31219501e+01 -2.26250357e+00 -2.48810843e+00
#   5.65239901e-01  2.37176954e-01 -2.82991530e-02 -1.21055333e-02
#  -1.50964700e-03  1.44848119e-04  9.11399320e-05  9.00152616e-06
#   2.83888983e-06 -3.80280979e-08 -1.45505282e-07 -8.52166233e-09]
# [ 0.00000000e+00  1.27927433e+01 -2.02383289e+00 -2.28969895e+00
#   4.79644237e-01  2.00280348e-01 -1.72236620e-02 -9.33882522e-03
#  -2.09197850e-03  7.34243057e-05  9.79784807e-05  8.32533892e-06
#   3.21634703e-06  1.10833966e-09 -1.54828444e-07 -8.46657151e-09]
# [ 0.00000000e+00  1.24635559e+01 -1.78519194e+00 -2.09132846e+00
#   3.94064874e-01  1.63401195e-01 -6.15123508e-03 -6.57510561e-03
#  -2.67406947e-03  2.23309050e-06  1.04809980e-04  7.64109034e-06
#   3.59378408e-06  4.03279348e-08 -1.64148532e-07 -8.41074305e-09]
# [ 0.00000000e+00  1.21345791e+01 -1.55489452e+00 -1.89313145e+00
#   3.11617908e-01  1.26592508e-01  4.50856030e-03 -3.82071899e-03
# ...

# %%
len(lasso_coeff)
# Out:
# 41

# %%
a = pd.concat([pd.DataFrame([i]) for i in lasso_coeff],ignore_index=True)

# %%
a
# Out:
#      0          1         2         3         4         5         6   \
# 0   0.0  13.121950 -2.262504 -2.488108  0.565240  0.237177 -0.028299
# 1   0.0  12.792743 -2.023833 -2.289699  0.479644  0.200280 -0.017224
# 2   0.0  12.463556 -1.785192 -2.091328  0.394065  0.163401 -0.006151
# 3   0.0  12.134579 -1.554895 -1.893131  0.311618  0.126593  0.004509
# 4   0.0  11.807089 -1.328107 -1.695671  0.231282  0.089915  0.014759
# 5   0.0  11.485942 -1.102115 -1.504577  0.151232  0.055089  0.024980
# 6   0.0  11.159216 -0.876445 -1.307956  0.071478  0.018691  0.035127
# 7   0.0  10.947481 -0.686389 -1.196120  0.000000 -0.000000  0.044849
# 8   0.0  10.743692 -0.716489 -1.104396 -0.000000 -0.010722  0.046584
# 9   0.0  10.478413 -0.687761 -0.953993 -0.006914 -0.036628  0.047139
# 10  0.0  10.208559 -0.605865 -0.797392 -0.028097 -0.064254  0.048795
# 11  0.0   9.931658 -0.517906 -0.635789 -0.051406 -0.092857  0.050699
# 12  0.0   9.651128 -0.427015 -0.471718 -0.075887 -0.121926  0.052762
# ...

# %%
lasso_coeff[0]
# Out:
# array([ 0.00000000e+00,  1.31219501e+01, -2.26250357e+00, -2.48810843e+00,
#         5.65239901e-01,  2.37176954e-01, -2.82991530e-02, -1.21055333e-02,
#        -1.50964700e-03,  1.44848119e-04,  9.11399320e-05,  9.00152616e-06,
#         2.83888983e-06, -3.80280979e-08, -1.45505282e-07, -8.52166233e-09])

# %%
lasso_coeff[-1]
# Out:
# array([ 0.00000000e+00,  7.88870094e+00, -0.00000000e+00,  0.00000000e+00,
#        -1.85898955e-01, -1.23358770e-01,  6.16150279e-02,  5.50627671e-03,
#        -5.69927763e-03,  2.25518386e-04,  1.07848202e-04, -1.14338282e-05,
#         6.91075358e-06, -2.01785707e-07, -2.29201993e-07,  8.47531461e-09])

# %%
ridge_coeff = []

for alpha in ALPHAS: 
    ridge = Ridge(alpha= alpha, max_iter=1000000)
    reg_r = ridge.fit(PolynomialFeatures(degree=15).fit_transform(X),y)
    print(reg_r.coef_)
    
    ridge_coeff.append(reg_r.coef_)
# Out:
# [ 0.00000000e+00  1.35008881e+01  3.54283625e-01 -2.75581283e+00
#  -1.26567426e+00  1.35838904e-01  4.59487444e-01  5.34645514e-02
#  -6.38127986e-02 -1.10943112e-02  4.18730937e-03  8.66791604e-04
#  -1.30847719e-04 -3.06147442e-05  1.56946652e-06  4.06505269e-07]
# [ 0.00000000e+00  1.32921029e+01  3.59861322e-01 -2.48952451e+00
#  -1.27273821e+00  2.65832804e-02  4.61868244e-01  7.41531288e-02
#  -6.41661212e-02 -1.31619271e-02  4.21331467e-03  9.79527173e-04
#  -1.31778289e-04 -3.37860787e-05  1.58237990e-06  4.42528255e-07]
# [ 0.00000000e+00  1.30975245e+01  3.63964045e-01 -2.24290983e+00
#  -1.27853041e+00 -7.42686677e-02  4.63866990e-01  9.32100397e-02
#  -6.44663380e-02 -1.50635247e-02  4.23558923e-03  1.08308410e-03
#  -1.32580170e-04 -3.66962820e-05  1.59356117e-06  4.75556878e-07]
# [ 0.00000000e+00  1.29156629e+01  3.66804443e-01 -2.01389994e+00
#  -1.28322022e+00 -1.67602715e-01  4.65532621e-01  1.10807624e-01
# ...

# %%
print(lasso_coeff[0],"\n", lasso_coeff[-1])
# Out:
# [ 0.00000000e+00  1.31219501e+01 -2.26250357e+00 -2.48810843e+00
#   5.65239901e-01  2.37176954e-01 -2.82991530e-02 -1.21055333e-02
#  -1.50964700e-03  1.44848119e-04  9.11399320e-05  9.00152616e-06
#   2.83888983e-06 -3.80280979e-08 -1.45505282e-07 -8.52166233e-09]
#  [ 0.00000000e+00  7.88870094e+00 -0.00000000e+00  0.00000000e+00
#  -1.85898955e-01 -1.23358770e-01  6.16150279e-02  5.50627671e-03
#  -5.69927763e-03  2.25518386e-04  1.07848202e-04 -1.14338282e-05
#   6.91075358e-06 -2.01785707e-07 -2.29201993e-07  8.47531461e-09]

# %%
for alpha in ALPHAS:
    plot_fit(make_model(degree = 15,penalty='L1', alpha = alpha).fit(X_train, y_train))

# %% [markdown]
# #### L2

# %%
for alpha in ALPHAS:
    plot_fit(make_model(degree = 15,penalty='L2', alpha = alpha).fit(X_train, y_train))

# %% [markdown]
# #### Summary

# %% [markdown]
# Сначала хотел посмотреть по коэффициентам, которые должны зануляться с увеличением $\alpha$. Но поскольку полином 15 степени, коэффициенты и так маленькие. Далее отобразил результаты приближения, на которых видно, что с увеличением параметра $\alpha$ прямая целевая прямая " выравнивается". То есть, увеличение параметра $\alpha$ влечет за собой увеличение штрафа модели, что в свою очередь уменьшает веса параметров модели. В итоге мы и получаем более линейное, устойчивое к выбросам, приближение.

# %% [markdown]
# ### Excercise 2 - Sparsity (4 points)

# %% [markdown]
# Lasso can also be used for **feature selection** since L1 is [more likely to produce zero coefficients](https://explained.ai/regularization/).
#
# Is it indeed happening?
#
# Please do a discovery on your own and find that out empirically (both for **L1** and **L2**). Let's use `degree=15` and `alpha` from `ALPHAS`.

# %% [markdown]
# #### L1

# %%
lasso = Lasso(max_iter=1000000)
coefs = []

for alpha in ALPHAS: 
    lasso.set_params(alpha=alpha)
    lasso.fit(PolynomialFeatures(degree=15).fit_transform(X), y)
    coefs.append(lasso.coef_)

# %%
plt.subplots(figsize=(10,10) )
ax = plt.gca()
ax.plot(ALPHAS, coefs,'--', linewidth = 1)
ax.set_xscale('log')
plt.axis('tight')
plt.xlabel('alpha')
plt.ylabel('weights')
# Out:
# Text(0, 0.5, 'weights')

# %%
coefs
# Out:
# [array([ 0.00000000e+00,  1.31219501e+01, -2.26250357e+00, -2.48810843e+00,
#          5.65239901e-01,  2.37176954e-01, -2.82991530e-02, -1.21055333e-02,
#         -1.50964700e-03,  1.44848119e-04,  9.11399320e-05,  9.00152616e-06,
#          2.83888983e-06, -3.80280979e-08, -1.45505282e-07, -8.52166233e-09]),
#  array([ 0.00000000e+00,  1.27927433e+01, -2.02383289e+00, -2.28969895e+00,
#          4.79644237e-01,  2.00280348e-01, -1.72236620e-02, -9.33882522e-03,
#         -2.09197850e-03,  7.34243057e-05,  9.79784807e-05,  8.32533892e-06,
#          3.21634703e-06,  1.10833966e-09, -1.54828444e-07, -8.46657151e-09]),
#  array([ 0.00000000e+00,  1.24635559e+01, -1.78519194e+00, -2.09132846e+00,
#          3.94064874e-01,  1.63401195e-01, -6.15123508e-03, -6.57510561e-03,
#         -2.67406947e-03,  2.23309050e-06,  1.04809980e-04,  7.64109034e-06,
#          3.59378408e-06,  4.03279348e-08, -1.64148532e-07, -8.41074305e-09]),
# ...

# %% [markdown]
# #### L2

# %%
ridge = Ridge( max_iter=1000000)
coefs_r = []

for alpha in ALPHAS: 
    ridge.set_params(alpha=alpha)
    ridge.fit(PolynomialFeatures(degree=15).fit_transform(X), y)
    coefs_r.append(ridge.coef_)

# %%
plt.subplots(figsize=(10,10) )
ax = plt.gca()
ax.plot(ALPHAS, coefs_r,'--', linewidth = 1)
ax.set_xscale('log')
plt.axis('tight')
plt.xlabel('alpha')
plt.ylabel('weights')
# Out:
# Text(0, 0.5, 'weights')

# %% [markdown]
# #### Summary

# %% [markdown]
# Регуляризация lasso может использоваться для feature selection. На построенном графике весов модели видно, что некоторые веса параметров модели стремятся к нулю при увеличении параметра $\alpha$. Этого не происходит в ridge регрессии так как, в ней для регуляризации используется норма l2, представляющая собой круг на плоскоти, а в lasso используется норма l1, представляющая собой квадрат на плоскости. Минимальное расстояние, заданное нормой l1- квадратом, от целевой точки до любой точки целевой функции может зависеть только от одного параметра(когда расстояние коллинеарно одной из осей). Но если расстояние задано нормой l2, то функция потерь всегда будет зависеть от двух параметров на плоскости.

# %% [markdown]
# ### Excercise 3 - Scaling (2 points)

# %% [markdown]
# As a general rule, it is recommended to scale input features before fitting a regularized model so that the features/inputs take values in similar ranges. One common way of doing so is to standardize the inputs and that is exactly what our pipeline  second step (`StandardScaler`) is responsible for.
#
# Why is scaling important? What are the underlying reasons?

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
data = [[10, 4000], [14, 3266], [9, 8976], [17, 5491]]

# %%
a = pd.DataFrame(data, columns = ['param1', 'param2'])

# %%
a
# Out:
#    param1  param2
# 0      10    4000
# 1      14    3266
# 2       9    8976
# 3      17    5491

# %%
a['target'] = np.random.normal(10000, 1000, 4)

# %%
a
# Out:
#    param1  param2        target
# 0      10    4000   9198.172157
# 1      14    3266  11384.015719
# 2       9    8976  11405.205306
# 3      17    5491  11392.325753

# %%
ridge_ex = Ridge(alpha= 0.2,  max_iter=1000000)
ridge_ex.fit(a[['param1', 'param2']], a['target'])
# Out:
# Ridge(alpha=0.2, max_iter=1000000)

# %%
ridge_ex.coef_
# Out:
# array([217.49508234,   0.29921295])

# %%
scaler = MinMaxScaler()
scaler.fit(a)
# Out:
# MinMaxScaler()

# %%
a = pd.DataFrame(scaler.transform(a), columns = ['param1', 'param2','target'])

# %%
ridge_ex = Ridge(alpha= 0.2,  max_iter=1000000)
ridge_ex.fit(a[['param1', 'param2']], a['target'])
# Out:
# Ridge(alpha=0.2, max_iter=1000000)

# %%
ridge_ex.coef_
# Out:
# array([0.51633824, 0.48989535])

# %%
a
# Out:
#    param1    param2    target
# 0   0.125  0.128546  0.000000
# 1   0.625  0.000000  0.990399
# 2   0.000  1.000000  1.000000
# 3   1.000  0.389667  0.994164

# %% [markdown]
# Так как масштаб значений параметров может сильно отличаться в реальных задачах, используют прием стандартизации.
# При котором, все данные модели приводятся к одному масштабу. Для примера продемострирую другой популярный
# способ стандартизации MinMax. Первый параметр принимает значения [10,20), а второй [400,900). Например, строя
# линейную модель с регуляризацией, каждый из параметров штрафуется одинаково. Получается, что вклад в регуляризацию
# будет разным. Поэтому, стандартизация позволяет штрафовать модель равномерно, что положительно скажется на точности
# модели.
